# %%
import tweepy
import csv
import pandas as pd
from tweepy.streaming import StreamListener
from tweepy import Stream
import time

# %%
#input your credentials here
consumer_key = "XXXXXXXX"
consumer_secret = "XXXXXXXX"
access_token = "XXXXXXXX"
access_token_secret = "XXXXXXXX"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
csvFile = open('ua7.csv', 'a')
csvWriter = csv.writer(csvFile)
                
df= pd.DataFrame()
vdf= pd.DataFrame()

# Creation of lists to add to dataframe
dates = []
tweetid = []
tweettext = []
tweetcoordinates = []
usercoordinates = []
username = []

     
#iterating through hashtags to fetch tweets 

# Parameters for function: enter latitude, longitude of area you want
def find_relevant_tweets(lat,long):
    count=0
    try:
        # Will search specific words or hashtags inside radius around chosen lat/long
        word_list = ['#wildfires']
        for word in word_list:
            for tweet in tweepy.Cursor(api.search,
                                        # Latitude and longitude variables are used to designate center point middle of radius
                                        # Can modify mi radius here, currently set to 50 mile radius around center point
                                       q=word+'\ngeocode:"'+str(lat)+','+str(long)+',50mi"',
                                       # Currently only scrapes for 3k tweets
                                       count=3000,
                                       # Can change language of items
                                       lang="en",
                                       since="2019-10-27").items():
                
                # Only scrapes for tweets and not retweets, can remove this if you want to capture all
                if (not tweet.retweeted) and ('RT @' not in tweet.text):

                    count+=1
                    if count >3000:
                        break
                    dates.append(tweet.created_at)
                    tweetid.append(tweet.id)
                    tweettext.append(tweet.text)
                    # Check statement for if there are tweet coordinates associated with tweets
                    # If there are coordinates it tracks them and adds to list
                    if (tweet.coordinates!=None):
                        tweetcoordinates.append(tweet.coordinates)
                    # Else if there are no coordinates with the tweets 
                    else:
                        tweetcoordinates.append(tweet.coordinates)
                    username.append(tweet.user.screen_name)
                    print(tweet.user.screen_name)
#                     urls.append(tweet.entities['urls'])
#                     print(tweepy.get_user(tweet.user))
                    
    except BaseException as e:
        print('failed on_status,',str(e))
        time.sleep(5)

    # Creation of dataframe with lists
    vdf['Date']= dates
    vdf['tweet id']= tweetid
    vdf['tweet text']=tweettext
    vdf['Geolocation']=tweetcoordinates
    vdf['Username']=username
    
    # Checks for dubplicate tweets
    result_df1 = vdf.drop_duplicates(subset=['tweet text'], keep='first')

    return result_df1

#writing dataframe to csv
# vdf.to_csv('firetweets.csv', encoding='utf-8')

# %%
# creates new dataframe from function
vdf = find_relevant_tweets(34.328,-119.008)

# %%
# Geolocation data and urls are stored in json may need cleaning
print("Total tweets:", vdf.shape[0])
print("Tweets with geolocations:", vdf[~vdf['Geolocation'].isna()].shape[0])

# Check if any entries have na values in geolocation
vdf[~vdf['Geolocation'].isna()]
# Out:
# Total tweets: 1403
# Tweets with geolocations: 20
#                     Date             tweet id  \
# 105  2019-11-02 04:55:17  1190492551901351937
# 136  2019-11-02 02:24:50  1190454690779025408
# 166  2019-11-02 00:29:21  1190425627297538049
# 171  2019-11-02 00:12:01  1190421268215943168
# 187  2019-11-01 23:02:54  1190403872247955456
# 203  2019-11-01 22:14:45  1190391756384280576
# 263  2019-11-01 19:55:07  1190356615687335936
# 267  2019-11-01 19:48:12  1190354874724241409
# 327  2019-11-01 18:54:32  1190341369593597952
# 348  2019-11-01 18:38:13  1190337263026102272
# 402  2019-11-01 17:21:02  1190317838306828288
# 439  2019-11-01 16:43:20  1190308350015131650
# 526  2019-11-01 14:40:58  1190277558857682945
# 593  2019-11-01 12:34:32  1190245740569694208
# 648  2019-11-01 10:49:58  1190219423614820352
# 661  2019-11-01 09:56:55  1190206073430392833
# 666  2019-11-01 09:27:06  1190198568826658816
# 905  2019-11-01 05:46:26  1190143035616612352
# 1074 2019-11-01 04:11:26  1190119129048465410
# 1275 2019-11-01 02:40:17  1190096192887250945
#
#                                              tweet text  \
# 105   Some scenes of Friday’s firefight in Saticoy a...
# 136   Smoke from Maria fire has drifted into our val...
# 166   Esteban Minero, Katelyn Magee, #Farmworkers, #...
# 171   The #MariaFire #Camarillo #California #PhotogB...
# 187   Hopefully this is the last of it....Thinking o...
# 203   MSB Disaster Recovery Services is here when yo...
# 263   #11-1 1 pm.  \nRetardant is slowing, but not s...
# 267   11-1 12:45 pm.  \nTodd Road, Santa Paul, Ca \n...
# 327   #Mariafire #Saticoy #Somis #SantaPaula @ Camar...
# 348   Current view of #MariaFire from hospital hill ...
# 402   The #MariaFire broke out in Santa Paula, CA la...
# 439   @csuci Police attended the 8:00 a.m. Ventura C...
# 526   #MariaFire 🔥 unofficial, automated update.\n~5...
# 593   #MariaFire 🔥 unofficial, automated update.\n~5...
# 648   #MariaFire update.  3:30 am, 11-1.  \nSanta Pa...
# 661   #MariaFire: For those that want some reassuran...
# 666   There was something strange in the neighborhoo...
# 905   #MariaFire 🔥 unofficial, automated update.\n~5...
# 1074  #MariaFire 🔥 unofficial, automated update.\n~5...
# 1275  View from my backyard. This Sucks #Mariafire @...
#
#                                             Geolocation  \
# 105   {'type': 'Point', 'coordinates': [-119.068, 34...
# 136   {'type': 'Point', 'coordinates': [-120.088, 34...
# 166   {'type': 'Point', 'coordinates': [-119.068, 34...
# 171   {'type': 'Point', 'coordinates': [-119.0702346...
# 187   {'type': 'Point', 'coordinates': [-119.068, 34...
# 203   {'type': 'Point', 'coordinates': [-119.068, 34...
# 263   {'type': 'Point', 'coordinates': [-119.068, 34...
# 267   {'type': 'Point', 'coordinates': [-119.068, 34...
# 327   {'type': 'Point', 'coordinates': [-119.0391, 3...
# 348   {'type': 'Point', 'coordinates': [-119.0621728...
# 402   {'type': 'Point', 'coordinates': [-119.13599, ...
# 439   {'type': 'Point', 'coordinates': [-119.0391, 3...
# 526   {'type': 'Point', 'coordinates': [-118.997115,...
# 593   {'type': 'Point', 'coordinates': [-118.997115,...
# 648   {'type': 'Point', 'coordinates': [-119.068, 34...
# 661   {'type': 'Point', 'coordinates': [-119.182, 34...
# 666   {'type': 'Point', 'coordinates': [-119.0391, 3...
# 905   {'type': 'Point', 'coordinates': [-118.997115,...
# 1074  {'type': 'Point', 'coordinates': [-118.997115,...
# 1275  {'type': 'Point', 'coordinates': [-119.0391, 3...
#
#                                                    urls
# 105   [{'url': 'https://t.co/807Txwbt6X', 'expanded_...
# 136   [{'url': 'https://t.co/K2N5t39Q7v', 'expanded_...
# 166   [{'url': 'https://t.co/Zc5I5Z1UsF', 'expanded_...
# 171   [{'url': 'https://t.co/KJyEjUXTLZ', 'expanded_...
# 187   [{'url': 'https://t.co/pBxebaIiff', 'expanded_...
# 203   [{'url': 'https://t.co/ceEZktE8yc', 'expanded_...
# 263   [{'url': 'https://t.co/RiAkBQ1qM8', 'expanded_...
# 267   [{'url': 'https://t.co/dderGzwseZ', 'expanded_...
# 327   [{'url': 'https://t.co/PZjnteSA4G', 'expanded_...
# 348                                                  []
# 402   [{'url': 'https://t.co/wLFd2f1Q71', 'expanded_...
# 439   [{'url': 'https://t.co/U1LUIShTsl', 'expanded_...
# 526   [{'url': 'https://t.co/BCAN0nBqqe', 'expanded_...
# 593   [{'url': 'https://t.co/ORncrT10aQ', 'expanded_...
# 648   [{'url': 'https://t.co/nTiAH0zIqR', 'expanded_...
# 661   [{'url': 'https://t.co/fjYYWtfZ5p', 'expanded_...
# 666   [{'url': 'https://t.co/DEvRfPTUTi', 'expanded_...
# 905   [{'url': 'https://t.co/chgdd48559', 'expanded_...
# 1074  [{'url': 'https://t.co/nTuDoFghug', 'expanded_...
# 1275  [{'url': 'https://t.co/vFf1TRWy1y', 'expanded_...

# %%
# Creates new dataframe that don't have any na values in geolocation
geolocated_data = vdf[~vdf['Geolocation'].isna()]

# %%
# Function to pull the url alone instead of json values
def pull_url(row):
    if(len(row.urls)>0):
        return row.urls[0]['expanded_url']

# %%
# Applies function to all urls and creates new column called pulled
geolocated_data['pulled'] = geolocated_data.apply(pull_url, axis=1)
# Out:
# C:\Users\marti\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# Removes all entries that have na values in the new pulled url column
geolocated_data = geolocated_data[~geolocated_data['pulled'].isna()]

# %%
# Drops url column and keeps pulled column that contains cleaned urls
geolocated_data.drop('urls',axis=1)
# Out:
#                     Date             tweet id  \
# 105  2019-11-02 04:55:17  1190492551901351937
# 136  2019-11-02 02:24:50  1190454690779025408
# 166  2019-11-02 00:29:21  1190425627297538049
# 171  2019-11-02 00:12:01  1190421268215943168
# 187  2019-11-01 23:02:54  1190403872247955456
# 203  2019-11-01 22:14:45  1190391756384280576
# 263  2019-11-01 19:55:07  1190356615687335936
# 267  2019-11-01 19:48:12  1190354874724241409
# 327  2019-11-01 18:54:32  1190341369593597952
# 402  2019-11-01 17:21:02  1190317838306828288
# 439  2019-11-01 16:43:20  1190308350015131650
# 526  2019-11-01 14:40:58  1190277558857682945
# 593  2019-11-01 12:34:32  1190245740569694208
# 648  2019-11-01 10:49:58  1190219423614820352
# 661  2019-11-01 09:56:55  1190206073430392833
# 666  2019-11-01 09:27:06  1190198568826658816
# 905  2019-11-01 05:46:26  1190143035616612352
# 1074 2019-11-01 04:11:26  1190119129048465410
# 1275 2019-11-01 02:40:17  1190096192887250945
#
#                                              tweet text  \
# 105   Some scenes of Friday’s firefight in Saticoy a...
# 136   Smoke from Maria fire has drifted into our val...
# 166   Esteban Minero, Katelyn Magee, #Farmworkers, #...
# 171   The #MariaFire #Camarillo #California #PhotogB...
# 187   Hopefully this is the last of it....Thinking o...
# 203   MSB Disaster Recovery Services is here when yo...
# 263   #11-1 1 pm.  \nRetardant is slowing, but not s...
# 267   11-1 12:45 pm.  \nTodd Road, Santa Paul, Ca \n...
# 327   #Mariafire #Saticoy #Somis #SantaPaula @ Camar...
# 402   The #MariaFire broke out in Santa Paula, CA la...
# 439   @csuci Police attended the 8:00 a.m. Ventura C...
# 526   #MariaFire 🔥 unofficial, automated update.\n~5...
# 593   #MariaFire 🔥 unofficial, automated update.\n~5...
# 648   #MariaFire update.  3:30 am, 11-1.  \nSanta Pa...
# 661   #MariaFire: For those that want some reassuran...
# 666   There was something strange in the neighborhoo...
# 905   #MariaFire 🔥 unofficial, automated update.\n~5...
# 1074  #MariaFire 🔥 unofficial, automated update.\n~5...
# 1275  View from my backyard. This Sucks #Mariafire @...
#
#                                             Geolocation  \
# 105   {'type': 'Point', 'coordinates': [-119.068, 34...
# 136   {'type': 'Point', 'coordinates': [-120.088, 34...
# 166   {'type': 'Point', 'coordinates': [-119.068, 34...
# 171   {'type': 'Point', 'coordinates': [-119.0702346...
# 187   {'type': 'Point', 'coordinates': [-119.068, 34...
# 203   {'type': 'Point', 'coordinates': [-119.068, 34...
# 263   {'type': 'Point', 'coordinates': [-119.068, 34...
# 267   {'type': 'Point', 'coordinates': [-119.068, 34...
# 327   {'type': 'Point', 'coordinates': [-119.0391, 3...
# 402   {'type': 'Point', 'coordinates': [-119.13599, ...
# 439   {'type': 'Point', 'coordinates': [-119.0391, 3...
# 526   {'type': 'Point', 'coordinates': [-118.997115,...
# 593   {'type': 'Point', 'coordinates': [-118.997115,...
# 648   {'type': 'Point', 'coordinates': [-119.068, 34...
# 661   {'type': 'Point', 'coordinates': [-119.182, 34...
# 666   {'type': 'Point', 'coordinates': [-119.0391, 3...
# 905   {'type': 'Point', 'coordinates': [-118.997115,...
# 1074  {'type': 'Point', 'coordinates': [-118.997115,...
# 1275  {'type': 'Point', 'coordinates': [-119.0391, 3...
#
#                                                  pulled
# 105   https://twitter.com/i/web/status/1190492551901...
# 136   https://twitter.com/i/web/status/1190454690779...
# 166   https://twitter.com/i/web/status/1190425627297...
# 171   https://www.instagram.com/p/B4V6x1enFuf/?igshi...
# 187   https://twitter.com/i/web/status/1190403872247...
# 203   https://twitter.com/i/web/status/1190391756384...
# 263   https://www.instagram.com/p/B4VdNP4AOD9/?igshi...
# 267   https://twitter.com/i/web/status/1190354874724...
# 327   https://www.instagram.com/p/B4VWXDflRYN/?igshi...
# 402   https://twitter.com/i/web/status/1190317838306...
# 439   https://twitter.com/i/web/status/1190308350015...
# 526   https://twitter.com/i/web/status/1190277558857...
# 593   https://twitter.com/i/web/status/1190245740569...
# 648   https://twitter.com/i/web/status/1190219423614...
# 661   https://twitter.com/i/web/status/1190206073430...
# 666   https://twitter.com/i/web/status/1190198568826...
# 905   https://twitter.com/i/web/status/1190143035616...
# 1074  https://twitter.com/i/web/status/1190119129048...
# 1275  https://www.instagram.com/p/B4Tm8Nql9PN/?igshi...

# %%
final_output = geolocated_data[['Date','Geolocation','pulled']]

# %%
final_output.head()
# Out:
#                    Date                                        Geolocation  \
# 105 2019-11-02 04:55:17  {'type': 'Point', 'coordinates': [-119.068, 34...
# 136 2019-11-02 02:24:50  {'type': 'Point', 'coordinates': [-120.088, 34...
# 166 2019-11-02 00:29:21  {'type': 'Point', 'coordinates': [-119.068, 34...
# 171 2019-11-02 00:12:01  {'type': 'Point', 'coordinates': [-119.0702346...
# 187 2019-11-01 23:02:54  {'type': 'Point', 'coordinates': [-119.068, 34...
#
#                                                 pulled
# 105  https://twitter.com/i/web/status/1190492551901...
# 136  https://twitter.com/i/web/status/1190454690779...
# 166  https://twitter.com/i/web/status/1190425627297...
# 171  https://www.instagram.com/p/B4V6x1enFuf/?igshi...
# 187  https://twitter.com/i/web/status/1190403872247...

# %%
final_output.to_csv('final_output.csv')
